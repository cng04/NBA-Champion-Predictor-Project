# %% [markdown]
# # We will be training a Decision Tree Machine Learning Model on our data

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %%
ml_df = pd.read_csv("merged_stats_scores.csv")
del ml_df["Unnamed: 0"]

# %%
ml_df
# Out:
#            MP        FG       FGA       FG%        3P       3PA       3P%
# 0    0.122449  0.676259  0.551724  0.747573  0.312925  0.239474  0.847561  \
# 1    0.489796  0.482014  0.297414  0.766990  0.346939  0.318421  0.609756
# 2    0.428571  0.597122  0.422414  0.786408  0.380952  0.334211  0.695122
# 3    0.244898  0.532374  0.306034  0.844660  0.176871  0.131579  0.658537
# 4    0.061224  0.769784  0.737069  0.669903  0.741497  0.710526  0.670732
# ..        ...       ...       ...       ...       ...       ...       ...
# 796  0.244898  0.539568  0.737069  0.320388  0.693878  0.776316  0.408537
# 797  0.122449  0.553957  0.685345  0.398058  0.727891  0.773684  0.500000
# 798  0.306122  0.697842  0.728448  0.572816  0.639456  0.678947  0.487805
# 799  0.306122  0.892086  0.926724  0.640777  0.632653  0.647368  0.536585
# 800  0.367347  0.705036  0.637931  0.689320  0.578231  0.610526  0.475610
#
#            2P       2PA       2P%  ...       TRB       AST       STL
# 0    0.787879  0.706044  0.487013  ...  0.559006  0.600000  0.553846  \
# 1    0.553030  0.458791  0.636364  ...  0.366460  0.571429  0.815385
# 2    0.636364  0.521978  0.623377  ...  0.341615  0.642857  0.400000
# 3    0.795455  0.659341  0.571429  ...  0.335404  0.692857  0.400000
# 4    0.416667  0.329670  0.714286  ...  0.521739  0.585714  0.261538
# ..        ...       ...       ...  ...       ...       ...       ...
# 796  0.227273  0.260989  0.558442  ...  0.540373  0.521429  0.200000
# 797  0.204545  0.230769  0.597403  ...  0.453416  0.464286  0.384615
# 798  0.454545  0.357143  0.707792  ...  0.453416  0.521429  0.261538
# 799  0.674242  0.516484  0.688312  ...  0.602484  0.821429  0.323077
# 800  0.530303  0.370879  0.792208  ...  0.465839  0.614286  0.138462
#
#           BLK       TOV        PF       PTS  Year  Team  Score
# 0    0.310345  0.405063  0.514286  0.609948  1996   CHI    5.0
# 1    0.413793  0.822785  0.704762  0.591623  1996   OKC    4.0
# 2    0.448276  0.379747  0.400000  0.591623  1996   ORL    3.0
# 3    0.465517  0.468354  0.800000  0.539267  1996   UTA    3.0
# 4    0.310345  0.101266  0.200000  0.837696  1996   ATL    2.0
# ..        ...       ...       ...       ...   ...   ...    ...
# 796  0.362069  0.430380  0.295238  0.583770  2022   ORL    0.0
# 797  0.362069  0.430380  0.428571  0.636126  2022   POR    0.0
# 798  0.362069  0.379747  0.219048  0.743455  2022   SAC    0.0
# 799  0.431034  0.202532  0.142857  0.819372  2022   SAS    0.0
# 800  0.448276  0.253165  0.209524  0.698953  2022   WAS    0.0
#
# [801 rows x 25 columns]

# %% [markdown]
# **Indicating which columns the model will be trained on**

# %%
not_features = ["Year", "Team", "Score"]

features = ml_df.columns[~ml_df.columns.isin(not_features)]

# %%
features
# Out:
# Index(['MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'],
#       dtype='object')

# %%
score = ml_df["Score"]
