# %% [markdown]
# ## Further Data Cleaning

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
df = pd.read_csv("team_stats.csv")
del df["Unnamed: 0"]

# %%
df
# Out:
#         MP    FG   FGA    FG%    3P   3PA    3P%    2P   2PA    2P%  ...
# 0    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...  \
# 1    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# 2    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# 3    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# 4    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# ..     ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 796  241.8  40.6  86.0  0.472  10.5  30.6  0.342  30.1  55.4  0.543  ...
# 797  241.5  39.0  80.7  0.484   6.0  14.8  0.407  33.0  65.9  0.501  ...
# 798  242.1  39.1  81.4  0.480   4.0  12.2  0.331  35.1  69.2  0.507  ...
# 799  241.5  34.5  78.4  0.440   3.7  10.8  0.339  30.9  67.6  0.457  ...
# 800  242.4  36.2  81.4  0.445   5.5  15.3  0.362  30.7  66.1  0.464  ...
#
#       DRB   TRB   AST  STL  BLK   TOV    PF    PTS  Year  Team
# ...

# %% [markdown]
# **Combine teams that have different historical names**

# %%
replace_dict = {"NJN": "BRK", "CHA": "CHO", "CHH": "CHO", "VAN": "MEM", "NOH": "NOP", "NOK": "NOP", "SEA": "OKC", "WSB": "WAS"}
df["Team"] = df["Team"].replace(replace_dict)

# %%
df
# Out:
#         MP    FG   FGA    FG%    3P   3PA    3P%    2P   2PA    2P%  ...
# 0    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...  \
# 1    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# 2    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# 3    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# 4    240.3  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9  0.531  ...
# ..     ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 796  241.8  40.6  86.0  0.472  10.5  30.6  0.342  30.1  55.4  0.543  ...
# 797  241.5  39.0  80.7  0.484   6.0  14.8  0.407  33.0  65.9  0.501  ...
# 798  242.1  39.1  81.4  0.480   4.0  12.2  0.331  35.1  69.2  0.507  ...
# 799  241.5  34.5  78.4  0.440   3.7  10.8  0.339  30.9  67.6  0.457  ...
# 800  242.4  36.2  81.4  0.445   5.5  15.3  0.362  30.7  66.1  0.464  ...
#
#       DRB   TRB   AST  STL  BLK   TOV    PF    PTS  Year  Team
# ...

# %% [markdown]
# ## Adding Win Score

# %%
season = 2021

file_path = "DATA/TOR_{}.html".format(season)

href_target = "/playoffs/NBA_{}.html".format(season)

with open(file_path) as file:
    team_data = file.read()

soup = BeautifulSoup(team_data, "html.parser")

playoffs = soup.find("a", href=href_target)

print(playoffs)

if playoffs != None:
    print("found")
else:
    print("not found")
# Out:
# <a href="/playoffs/NBA_2021.html">Playoffs</a>
# found
